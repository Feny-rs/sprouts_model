# %% [markdown]
# <a href="https://colab.research.google.com/github/Feny-rs/sprouts_model/blob/master/cnn_dataset_baru.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow
# !pip install tensorflow
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="CLAcDuqXX6buLaKIgh29")
project = rf.workspace("politeknik-negeri-semarang-nurcn").project("yolo-sprouts-classification")
dataset = project.version(4).download("multiclass")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Yolo-Sprouts-Classification-4 in multiclass:: 100%|██████████| 1282/1282 [00:00<00:00, 5681.25it/s]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Define the path to your dataset directory
dataset_path = '/content/Yolo-Sprouts-Classification-4'

# Define image size and batch size
image_size = (640, 640)
batch_size = 32

# Create an image data generator with augmentation
datagen = ImageDataGenerator(
    rescale=1.0 / 255,
    horizontal_flip=True,
    vertical_flip=True,
    rotation_range=90,
    zoom_range=(0.0, 0.7),
    brightness_range=(0.8, 1.2),
    fill_mode="constant",
    cval=255,
)

# Load and preprocess the dataset
train_data = datagen.flow_from_directory(
    dataset_path,
    target_size=image_size,
    batch_size=batch_size,
    class_mode="categorical",
    subset="training",  # This is for multi-class classification
)

# Define and compile your machine learning model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(640, 640, 3)))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 output classes

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(train_data, epochs=10)  # Adjust the number of epochs as needed
# Out:
# Found 1274 images belonging to 3 classes.
# Epoch 1/10
# 40/40 [==============================] - 1023s 25s/step - loss: 2.9237 - accuracy: 0.7684
# Epoch 2/10
# 40/40 [==============================] - 1015s 25s/step - loss: 0.5718 - accuracy: 0.8430
# Epoch 3/10
# 40/40 [==============================] - 1007s 25s/step - loss: 0.5565 - accuracy: 0.8430
# Epoch 4/10
# 40/40 [==============================] - 1003s 25s/step - loss: 0.5528 - accuracy: 0.8430
# Epoch 5/10
# 40/40 [==============================] - 1005s 25s/step - loss: 0.5656 - accuracy: 0.8430
# Epoch 6/10
# 40/40 [==============================] - 1002s 25s/step - loss: 0.5697 - accuracy: 0.8430
# Epoch 7/10
# 40/40 [==============================] - 1004s 25s/step - loss: 0.5449 - accuracy: 0.8430
# Epoch 8/10
# 40/40 [==============================] - 1002s 25s/step - loss: 0.5315 - accuracy: 0.8430
# Epoch 9/10
# 40/40 [==============================] - 1001s 25s/step - loss: 0.5395 - accuracy: 0.8430
# ...

# %%
# !git config --global user.email "fenyyrahma@gmail.com"
# !git config --global user.name "Feny-rs"

# %%
# !git init
# !git add .
# !git commit -m "Initial commit"
# Out:
# Reinitialized existing Git repository in /content/.git/
# [master (root-commit) 221b8d3] Initial commit
#  1299 files changed, 52188 insertions(+)
#  create mode 100644 .config/.last_opt_in_prompt.yaml
#  create mode 100644 .config/.last_survey_prompt.yaml
#  create mode 100644 .config/.last_update_check.json
#  create mode 100644 .config/active_config
#  create mode 100644 .config/config_sentinel
#  create mode 100644 .config/configurations/config_default
#  create mode 100644 .config/default_configs.db
#  create mode 100644 .config/gce
#  create mode 100644 .config/logs/2023.10.12/13.24.23.720152.log
#  create mode 100644 .config/logs/2023.10.12/13.24.55.075099.log
#  create mode 100644 .config/logs/2023.10.12/13.25.07.457568.log
#  create mode 100644 .config/logs/2023.10.12/13.25.22.709674.log
#  create mode 100644 .config/logs/2023.10.12/13.25.35.872929.log
#  create mode 100644 .config/logs/2023.10.12/13.25.36.773088.log
# ...

# %%
# !git remote add origin https://github.com/Feny-rs/sprouts_model.git
# Out:
# error: remote origin already exists.

# %%
# !git log
# Out:
# commit 221b8d30dce1984daa510e6da8ef7d835ac1d830 (HEAD -> master)
# Author: Feny-rs <fenyyrahma@gmail.com>
# Date:   Sat Oct 14 05:15:32 2023 +0000
#
#     Initial commit

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git push https://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@github.com/Feny-rs/sprouts_model.git
# Out:
# Enumerating objects: 1307, done.
# Counting objects: 100% (1307/1307), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (1300/1300), done.
# Writing objects: 100% (1307/1307), 47.07 MiB | 6.64 MiB/s, done.
# Total 1307 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), done.
# To https://github.com/Feny-rs/sprouts_model.git
#  * [new branch]      master -> master
